# %% [markdown]
# <a href="https://colab.research.google.com/github/jack0928/computer-vision-fundamentals/blob/main/03_mnist_dmlp_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import tensorflow as tf
import tensorflow.keras.datasets as ds

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.optimizers import Adam

# ======================
# MNIST 데이터 로드
# ======================
(x_train, y_train), (x_test, y_test) = ds.mnist.load_data()

# ======================
# 데이터 전처리
# ======================
x_train = x_train.reshape(60000, 784)
x_test = x_test.reshape(10000, 784)

x_train = x_train.astype(np.float32) / 255.0
x_test = x_test.astype(np.float32) / 255.0

y_train = tf.keras.utils.to_categorical(y_train, 10)
y_test = tf.keras.utils.to_categorical(y_test, 10)

# ======================
# DMLP 모델 정의
# ======================
dmlp = Sequential()
dmlp.add(Dense(units=1024, activation='relu', input_shape=(784,)))
dmlp.add(Dense(units=512, activation='relu'))
dmlp.add(Dense(units=512, activation='relu'))
dmlp.add(Dense(units=10, activation='softmax'))

# ======================
# 컴파일
# ======================
dmlp.compile(
    loss='categorical_crossentropy',
    optimizer=Adam(learning_rate=0.0001),
    metrics=['accuracy']
)

# ======================
# 학습
# ======================
hist = dmlp.fit(
    x_train,
    y_train,
    batch_size=128,
    epochs=50,
    validation_data=(x_test, y_test),
    verbose=2
)

# ======================
# 평가
# ======================
print('정확률=', dmlp.evaluate(x_test, y_test, verbose=0)[1] * 100)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 2s 0us/step
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/dense.py:93: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 469/469 - 6s - 12ms/step - accuracy: 0.9003 - loss: 0.3913 - val_accuracy: 0.9492 - val_loss: 0.1761
# Epoch 2/50
# 469/469 - 1s - 3ms/step - accuracy: 0.9594 - loss: 0.1405 - val_accuracy: 0.9659 - val_loss: 0.1143
# Epoch 3/50
# 469/469 - 1s - 3ms/step - accuracy: 0.9725 - loss: 0.0955 - val_accuracy: 0.9700 - val_loss: 0.0992
# Epoch 4/50
# 469/469 - 1s - 3ms/step - accuracy: 0.9795 - loss: 0.0706 - val_accuracy: 0.9763 - val_loss: 0.0764
# Epoch 5/50
# 469/469 - 2s - 4ms/step - accuracy: 0.9843 - loss: 0.0534 - val_accuracy: 0.9775 - val_loss: 0.0746
# Epoch 6/50
# 469/469 - 2s - 4ms/step - accuracy: 0.9883 - loss: 0.0409 - val_accuracy: 0.9782 - val_loss: 0.0715
# Epoch 7/50
# 469/469 - 2s - 3ms/step - accuracy: 0.9910 - loss: 0.0321 - val_accuracy: 0.9799 - val_loss: 0.0632
# Epoch 8/50
# 469/469 - 1s - 3ms/step - accuracy: 0.9936 - loss: 0.0234 - val_accuracy: 0.9796 - val_loss: 0.0637
# Epoch 9/50
# 469/469 - 2s - 3ms/step - accuracy: 0.9952 - loss: 0.0184 - val_accuracy: 0.9787 - val_loss: 0.0683
# Epoch 10/50
# 469/469 - 2s - 3ms/step - accuracy: 0.9968 - loss: 0.0137 - val_accuracy: 0.9805 - val_loss: 0.0666
# Epoch 11/50
# 469/469 - 2s - 3ms/step - accuracy: 0.9976 - loss: 0.0105 - val_accuracy: 0.9814 - val_loss: 0.0635
# Epoch 12/50
# 469/469 - 2s - 4ms/step - accuracy: 0.9982 - loss: 0.0084 - val_accuracy: 0.9810 - val_loss: 0.0681
# Epoch 13/50
# 469/469 - 2s - 4ms/step - accuracy: 0.9984 - loss: 0.0071 - val_accuracy: 0.9803 - val_loss: 0.0655
# Epoch 14/50
# 469/469 - 2s - 3ms/step - accuracy: 0.9985 - loss: 0.0065 - val_accuracy: 0.9806 - val_loss: 0.0683
# Epoch 15/50
# 469/469 - 2s - 3ms/step - accuracy: 0.9993 - loss: 0.0036 - val_accuracy: 0.9820 - val_loss: 0.0650
# Epoch 16/50
# 469/469 - 2s - 3ms/step - accuracy: 0.9994 - loss: 0.0031 - val_accuracy: 0.9809 - val_loss: 0.0744
# Epoch 17/50
# 469/469 - 2s - 3ms/step - accuracy: 0.9979 - loss: 0.0071 - val_accuracy: 0.9764 - val_loss: 0.0969
# Epoch 18/50
# 469/469 - 2s - 3ms/step - accuracy: 0.9991 - loss: 0.0040 - val_accuracy: 0.9814 - val_loss: 0.0743
# Epoch 19/50
# 469/469 - 2s - 3ms/step - accuracy: 0.9997 - loss: 0.0017 - val_accuracy: 0.9824 - val_loss: 0.0720
# Epoch 20/50
# 469/469 - 2s - 4ms/step - accuracy: 0.9985 - loss: 0.0051 - val_accuracy: 0.9809 - val_loss: 0.0730
# Epoch 21/50
# 469/469 - 2s - 3ms/step - accuracy: 0.9994 - loss: 0.0029 - val_accuracy: 0.9822 - val_loss: 0.0717
# Epoch 22/50
# 469/469 - 2s - 3ms/step - accuracy: 0.9997 - loss: 0.0013 - val_accuracy: 0.9808 - val_loss: 0.0850
# Epoch 23/50
# 469/469 - 2s - 3ms/step - accuracy: 0.9996 - loss: 0.0018 - val_accuracy: 0.9804 - val_loss: 0.0888
# Epoch 24/50
# 469/469 - 2s - 3ms/step - accuracy: 0.9975 - loss: 0.0077 - val_accuracy: 0.9812 - val_loss: 0.0794
# Epoch 25/50
# 469/469 - 3s - 5ms/step - accuracy: 0.9999 - loss: 8.1256e-04 - val_accuracy: 0.9838 - val_loss: 0.0721
# Epoch 26/50
# 469/469 - 2s - 3ms/step - accuracy: 0.9999 - loss: 5.2755e-04 - val_accuracy: 0.9834 - val_loss: 0.0732
# Epoch 27/50
# 469/469 - 2s - 4ms/step - accuracy: 1.0000 - loss: 2.8244e-04 - val_accuracy: 0.9829 - val_loss: 0.0747
# Epoch 28/50
# 469/469 - 1s - 3ms/step - accuracy: 1.0000 - loss: 1.5932e-04 - val_accuracy: 0.9832 - val_loss: 0.0762
# Epoch 29/50
# 469/469 - 2s - 3ms/step - accuracy: 1.0000 - loss: 1.1037e-04 - val_accuracy: 0.9840 - val_loss: 0.0769
# Epoch 30/50
# 469/469 - 2s - 3ms/step - accuracy: 1.0000 - loss: 7.6401e-05 - val_accuracy: 0.9838 - val_loss: 0.0772
# Epoch 31/50
# 469/469 - 2s - 3ms/step - accuracy: 1.0000 - loss: 5.8830e-05 - val_accuracy: 0.9836 - val_loss: 0.0785
# Epoch 32/50
# 469/469 - 1s - 3ms/step - accuracy: 1.0000 - loss: 4.6531e-05 - val_accuracy: 0.9837 - val_loss: 0.0798
# Epoch 33/50
# 469/469 - 1s - 3ms/step - accuracy: 1.0000 - loss: 3.7666e-05 - val_accuracy: 0.9841 - val_loss: 0.0814
# Epoch 34/50
# 469/469 - 2s - 4ms/step - accuracy: 1.0000 - loss: 3.2494e-05 - val_accuracy: 0.9839 - val_loss: 0.0828
# Epoch 35/50
# 469/469 - 2s - 4ms/step - accuracy: 1.0000 - loss: 2.6826e-05 - val_accuracy: 0.9843 - val_loss: 0.0842
# Epoch 36/50
# 469/469 - 2s - 3ms/step - accuracy: 1.0000 - loss: 2.1207e-05 - val_accuracy: 0.9839 - val_loss: 0.0861
# Epoch 37/50
# 469/469 - 2s - 3ms/step - accuracy: 1.0000 - loss: 1.9866e-05 - val_accuracy: 0.9841 - val_loss: 0.0871
# Epoch 38/50
# 469/469 - 1s - 3ms/step - accuracy: 1.0000 - loss: 1.4826e-05 - val_accuracy: 0.9841 - val_loss: 0.0891
# Epoch 39/50
# 469/469 - 2s - 3ms/step - accuracy: 1.0000 - loss: 1.1943e-05 - val_accuracy: 0.9837 - val_loss: 0.0923
# Epoch 40/50
# 469/469 - 2s - 3ms/step - accuracy: 0.9968 - loss: 0.0119 - val_accuracy: 0.9779 - val_loss: 0.0946
# Epoch 41/50
# 469/469 - 2s - 3ms/step - accuracy: 0.9991 - loss: 0.0035 - val_accuracy: 0.9819 - val_loss: 0.0852
# Epoch 42/50
# 469/469 - 2s - 4ms/step - accuracy: 0.9999 - loss: 5.5403e-04 - val_accuracy: 0.9831 - val_loss: 0.0787
# Epoch 43/50
# 469/469 - 2s - 3ms/step - accuracy: 1.0000 - loss: 1.3158e-04 - val_accuracy: 0.9834 - val_loss: 0.0784
# Epoch 44/50
# 469/469 - 2s - 3ms/step - accuracy: 1.0000 - loss: 7.9528e-05 - val_accuracy: 0.9835 - val_loss: 0.0799
# Epoch 45/50
# 469/469 - 3s - 5ms/step - accuracy: 1.0000 - loss: 6.0873e-05 - val_accuracy: 0.9838 - val_loss: 0.0811
# Epoch 46/50
# 469/469 - 2s - 3ms/step - accuracy: 1.0000 - loss: 4.8624e-05 - val_accuracy: 0.9837 - val_loss: 0.0820
# Epoch 47/50
# 469/469 - 2s - 3ms/step - accuracy: 1.0000 - loss: 3.8581e-05 - val_accuracy: 0.9836 - val_loss: 0.0835
# Epoch 48/50
# 469/469 - 2s - 3ms/step - accuracy: 1.0000 - loss: 3.1076e-05 - val_accuracy: 0.9834 - val_loss: 0.0846
# Epoch 49/50
# 469/469 - 2s - 4ms/step - accuracy: 1.0000 - loss: 2.5331e-05 - val_accuracy: 0.9834 - val_loss: 0.0860
# Epoch 50/50
# 469/469 - 2s - 3ms/step - accuracy: 1.0000 - loss: 2.0552e-05 - val_accuracy: 0.9835 - val_loss: 0.0875
# 정확률= 98.35000038146973
